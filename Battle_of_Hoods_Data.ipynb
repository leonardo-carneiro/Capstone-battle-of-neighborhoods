# %% [markdown]
# # Data

# %% [markdown]
# We scrape the names of the districts from Sao Paulo from the following link: http://www.mapas-sp.com/bairros.htm. There are 96 districts in the city of Sao Paulo. We, then, use the geocoder library in Python to get the geographical coordinates from the districts, and store them in a pandas dataframe.
#
# In order to explore and segment the districts according to nearby venues, we utilize the Foursquare API interface to extract the data and store it in a pandas dataframe. There are 296 different categories of venues and a total of 2,661 venues found on the Foursquare API.
#
# With these data at our disposal we will be able to cluster the districts, determine similarities accross them and provide help in potential relocations job related.
