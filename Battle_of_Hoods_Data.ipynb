# %% [markdown]
# # Data

# %% [markdown]
# To accomplish the goal of our report, we list all data sources utilized:
#
# + We scrape the followig Wikipedia page to extract the districts of the city of Sao Paulo: https://pt.wikipedia.org/wiki/Lista_dos_distritos_de_S%C3%A3o_Paulo_por_popula%C3%A7%C3%A3o
# + We use the geocoder library in Python to get the geographical coordinates from the districts
#
# With these data at our disposal, we create a pandas dataframe for further analysis. The dataframe consists of 96 rows, corresponding to the districts, and three columns (District, Latitude, Longitude).
